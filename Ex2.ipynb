# %% [markdown]
# <a href="https://colab.research.google.com/github/mizuirorivi/BigData_Analysis/blob/main/Ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Topic 1 : Basic Syntax for Markdown

# %% [markdown]
# ##1. Putting Headings:
# Select Markdown option instead of code and execute the
# cell.

# %%
# Heading level 1
## Heading level 2
### Heading level 3
#### Heading level 4
##### Heading level 5
###### Heading level 6
# Write the above lines in a cell, choose the markdown instead of Code in
# compile the markdown and print below code. DO NOT WRITE THESE LINES TOIn [ ]:
# __two underscores before and after the text__In [7]:
# _single underscore before and after the text_

# %% [markdown]
# #Heading level 1
# ##Heading level 2
# ###Heading level 3
# ####Heading level 4
# #####Heading level 5
# ######Heading level 6
# ##2. Writing Bold letters
# ###remove # in the below text for markdown

# %%
# __two underscores before and after the text__

# %% [markdown]
# **two underscores before and after the text**

# %% [markdown]
# ##3. Writing italic letters

# %%
# _single underscore before and after the text_

# %% [markdown]
# single underscore before and after the text

# %% [markdown]
# ##4. Dotted Points

# %%
# - Dash before text
# - will print the text
# - with numbered point

# %% [markdown]
# * Dot before text
# * will print the text
# * with numbered point

# %% [markdown]
# ## 5.Numbered points

# %%
# 1. sample
# 2. text
# 3. test

# %% [markdown]
# 1. sample
# 2. text
# 3. test

# %% [markdown]
# ##6. Creating Tables:

# %%
# | Heading 1 | Heading 2 |
# |-----------|-----------|
# | 1         | xx        |
# | 2         | yy        |

# %% [markdown]
# | Heading 1 | Heading 2 |
# |-----------|-----------|
# | 1         | xx        |
# | 2         | yy        |

# %% [markdown]
# ##7. Images:

# %%
# ![Apple](apple_image.jpg)

# %% [markdown]
# # ![Apple](/content/apple_image.jpg)

# %% [markdown]
# ##8. Underscore text

# %%
# <u>Underscore text </u>

# %% [markdown]
# <u>Underscore text </u>

# %% [markdown]
# ##9. Horizontal line

# %%
# ***

# %% [markdown]
# #Topic 2 : Basic Python Programming
# ## Step 1: print "Hello World"

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Step 2: Create a Numeric Variable

# %%
a = 10

# %% [markdown]
# ## Step 3: Print above created variable

# %%
print(a)
# Out:
# 10

# %% [markdown]
# ## Step 4: Print the type of above variable

# %%
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# ## Step 5: Create a String Variable & Print

# %%
string = "Hello"

# %% [markdown]
# ### Step 5.1: Access 2nd element in above string

# %%
print(string[1])
# Out:
# e

# %% [markdown]
# ### Step 5.2: Find the length of above string

# %%
print(len(string))
# Out:
# 5

# %% [markdown]
# ### Step 5.3: Create another String and compare the strings.

# %%
string2 = "World"
if string == string2:
    print("Both strings are the same.")
else:
  print("Both Strings are not same.")
# Out:
# Both Strings are not same.

# %% [markdown]
# ### Step 5.4: Perform Concatenation operation

# %%
string3 = string + string2
print(string3)

# %% [markdown]
# ## Step 6: Create a list

# %%
sampleList = [3, 5, 6, 18, 10]

# %% [markdown]
# ### Step 6.1: Find the length of above list.

# %%
print(len(sampleList))

# %% [markdown]
# ### Step 6.2: Iterate above list using for loop.

# %%
for i in sampleList:
    print(i)

# %% [markdown]
# ### Step 6.3: Add another element in to above list

# %%
sampleList.append(22)

# %% [markdown]
# ### Step 6.4: Remove one element from above list

# %%
sampleList.remove(3)

# %% [markdown]
# ### Step 6.5: Find the minimum and maximum numbers exists in above list.

# %%
print(min(sampleList))
print(max(sampleList))

# %% [markdown]
# ## Step 7: Getting input as a string from User

# %%
name = input("Enter your name: ")

# %% [markdown]
# ## Step 8: Displaying output: string

# %%
print("Hello " + name + "!")

# %% [markdown]
# ## Step 9: Getting input as an int from User

# %%
num = int(input("Enter a number: "))
print("You entered a number:", num)
# Out:
# Enter a number: 360
# You entered a number: 360

# %% [markdown]
# ## Step 10: Display the input

# %%
print(num)

# %% [markdown]
# ## Step 11: Different ways to print int and string

# %%
a = 20
b = 10
sum = a + b

# Several ways to print
print("The total sum of values a and b is: {}".format(sum))
print("The total sum of values a and b is: %d" %sum)
print("The total sum of values a and b is:", sum)
# Out:
# The total sum of values a and b is: 30
# The total sum of values a and b is: 30
# The total sum of values a and b is: 30

# %% [markdown]
# ## Step 12: Getting multiple inputs from the user

# %%
a, b, c = input("Enter any three values: ").split()

print("First number:", a)
print("Second number:", b)
print("Third number:", c)
# Out:
# Enter any three values: 1 20 3
# First number: 1
# Second number: 20
# Third number: 3

# %% [markdown]
# ##Step 13: Define a function using "def"

# %%
def HelloWorld():
    print("Hello World")

# %% [markdown]
# ## Step 14: Call the above function

# %%
HelloWorld()

# %% [markdown]
# # Topic 3: Advanced Python Programming
# ## 1. pip install Command:

# %%
## Syntax: !pip install package-name
Example: !pip install pami

# %% [markdown]
# ## 2. Reading and Processing .CSV file:

# %%
import csv

file = open('fileName.csv')
csvreader = csv.reader(file)
# Printing Column names in csv file
header = next(csvreader)
print(header)

# %% [markdown]
# ## 3. Reading CSV with pandas:

# %%
# Reading csv file into a dataframe
import pandas as pd

df = pd.read_csv('inputFileName.csv')
# If you get error to open the file using the above code give absolute path
# df = pd.read_csv('Exercise_1/inputFileName.csv')
# You can get absolute path by right click -> copy path.

# Printing the first rows of dataframe
print(df.head())

# Printing the column names
print(df.columns)

# Dropping columns from dataframe
print(df.drop('stationId', axis=1))
# Printing number of rows and columns in dataframe
print(df.shape)

# %% [markdown]
# ##4. How to add code description?

# %%
# Add the description about the code using comments.
def hello_world():
  # A simple comment preceding a simple print statement
  print("Hello World")
